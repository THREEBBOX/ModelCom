# %%
# %matplotlib inline
from BasicAction import *

# %%
graph = baseGraph()
filePath = 'Pdata2_33.xlsx'
file = baseFile()
data=file.openExcel(filePath,usecol=range(1,4))
print(data)
# Out:
# 2020-09-02 14:07:20,117 basicAction.py[line:46] INFO open Pdata2_33.xlsx success
# 2020-09-02 14:07:20,117 basicAction.py[line:46] INFO open Pdata2_33.xlsx success
# 2020-09-02 14:07:20,126 basicAction.py[line:46] INFO describe path save in E:\ModelCom\savedata\describeDir20200902\describe_Pdata2_33_14_07_20.xlsx
# 2020-09-02 14:07:20,126 basicAction.py[line:46] INFO describe path save in E:\ModelCom\savedata\describeDir20200902\describe_Pdata2_33_14_07_20.xlsx
# [[235.83  324.03  478.32 ]
#  [236.27  325.63  515.45 ]
#  [238.05  328.08  517.09 ]
#  [235.9       nan 514.89 ]
#  [236.76  268.82      nan]
#  [    nan 404.04  486.09 ]
#  [237.41  391.26  516.23 ]
#  [238.65  380.81      nan]
#  [237.61  388.02  435.35 ]
#  [238.03  206.43  487.675]]

# %%
data=np.nan_to_num(data)
sumdata = np.sum(data,axis=0)
print(sumdata)
# Out:
# [2134.51  3017.12  3951.095]

# %%
graph.bar(sumdata,xlables=["userA","userB","userC"],
          ylable="cosumer data",title="money from cosumer",color='#00FF7F')
# Out:
# 2020-09-02 14:07:20,474 basicAction.py[line:46] INFO bar :
#  titile:money from cosumer
#  listArray [2134.51  3017.12  3951.095]
# 2020-09-02 14:07:20,474 basicAction.py[line:46] INFO bar :
#  titile:money from cosumer
#  listArray [2134.51  3017.12  3951.095]
# 2020-09-02 14:07:20,552 basicAction.py[line:46] INFO save figure in E:\ModelCom\savedata\graphDir20200902\bar\money_from_cosumer14_07_20_bar.png
# 2020-09-02 14:07:20,552 basicAction.py[line:46] INFO save figure in E:\ModelCom\savedata\graphDir20200902\bar\money_from_cosumer14_07_20_bar.png

# %%
print("finish")
# Out:
# finish

# %%
import numpy as np
x = np.linspace(0,2*np.pi,300)
y1 = np.sin(x)
y2 = np.cos(x**2)
graph.plot([x,x],[y1,y2],legend=['$sin(x)$','$cos(x^2)$'],color=['r','b'])
# Out:
# 2020-09-02 14:07:20,969 basicAction.py[line:46] INFO draw plot E:\ModelCom\savedata\graphDir20200902\plot\input_titile14_07_20_plot.png
# 2020-09-02 14:07:20,969 basicAction.py[line:46] INFO draw plot E:\ModelCom\savedata\graphDir20200902\plot\input_titile14_07_20_plot.png

# %%
z=np.linspace(0,100,1000)
x=np.sin(z)*z
y=np.cos(z)*z
graph.line_3d(x,y,z)
# Out:
# 2020-09-02 14:08:06,871 basicAction.py[line:46] INFO line 3d
# 2020-09-02 14:08:06,871 basicAction.py[line:46] INFO line 3d
# 2020-09-02 14:08:08,127 basicAction.py[line:46] INFO draw line3d E:\ModelCom\savedata\graphDir20200902\3d_plot\input_tile14_08_06_3d_plot.png
# 2020-09-02 14:08:08,127 basicAction.py[line:46] INFO draw line3d E:\ModelCom\savedata\graphDir20200902\3d_plot\input_tile14_08_06_3d_plot.png

# %%
x=np.linspace(-6,6,30)
y=np.linspace(-6,6,30)
X,Y=np.meshgrid(x,y)
z=np.sin(np.sqrt(X**2+Y**2))
graph.gride_3d(X,Y,z)
# Out:
# 2020-09-02 14:10:11,458 basicAction.py[line:46] INFO grid 3d
# 2020-09-02 14:10:11,458 basicAction.py[line:46] INFO grid 3d
# 2020-09-02 14:10:11,533 basicAction.py[line:46] INFO draw grid 3d E:\ModelCom\savedata\graphDir20200902\3d_plot\input_title14_10_11_3d_plot.png
# 2020-09-02 14:10:11,533 basicAction.py[line:46] INFO draw grid 3d E:\ModelCom\savedata\graphDir20200902\3d_plot\input_title14_10_11_3d_plot.png

# %%
graph.surface_3d(X,Y,z)
# Out:
# 2020-09-02 14:13:32,257 basicAction.py[line:46] INFO surface 3d
# 2020-09-02 14:13:32,257 basicAction.py[line:46] INFO surface 3d
# 2020-09-02 14:13:32,381 basicAction.py[line:46] INFO draw surface 3d E:\ModelCom\savedata\graphDir20200902\3d_plot\input_title14_13_32_3d_plot.png
# 2020-09-02 14:13:32,381 basicAction.py[line:46] INFO draw surface 3d E:\ModelCom\savedata\graphDir20200902\3d_plot\input_title14_13_32_3d_plot.png

# %%
t=np.linspace(0,2*np.pi,100)
s=np.linspace(-1,1,100)
t,s=np.meshgrid(t,s)
x=((s/2)*np.cos(t/2)+2)*np.cos(t)
y=((s/2)*np.cos(t/2)+2)*np.sin(t)
z=(s/2)*np.sin(t/2)

graph.surface_3d(x,y,z)
# Out:
# 2020-09-02 14:16:57,949 basicAction.py[line:46] INFO surface 3d
# 2020-09-02 14:16:57,949 basicAction.py[line:46] INFO surface 3d
# 2020-09-02 14:16:58,222 basicAction.py[line:46] INFO draw surface 3d E:\ModelCom\savedata\graphDir20200902\3d_plot\input_title14_16_58_3d_plot.png
# 2020-09-02 14:16:58,222 basicAction.py[line:46] INFO draw surface 3d E:\ModelCom\savedata\graphDir20200902\3d_plot\input_title14_16_58_3d_plot.png
